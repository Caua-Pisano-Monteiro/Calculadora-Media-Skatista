# %%
#Armazenamento de notas
nota_skatista = []
#Recebimento de notas.
for i in range(1,6):
  nota = float(input(f'nota{i}:'))
  nota_skatista.append(nota)
print(nota_skatista)
#Calculando a média
def media(lista):
    #Puxando a maior e a menor nota
    maior_nota = max(nota_skatista)
    menor_nota = min(nota_skatista)
    #Removendo a maior e a menor nota
    nota_skatista.remove(maior_nota)
    nota_skatista.remove(menor_nota)
    #calculando a média
    return sum(nota_skatista)/len(nota_skatista)
media = media(nota_skatista)
print(f'A nota final do skatista é: {media}')
# Out:
# [3.0, 4.0, 6.0, 8.0, 9.0]
# A nota final do skatista é: 6.0
